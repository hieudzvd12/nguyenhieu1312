# %%
#W4A1
n = int(input())
Tong = 0
for i in range(1, n+1):
    if n + 1 <= 1001:
        Tong += i
    else:
        Tong = "khong co gia tri"
print(Tong)
# Out:
# khong co gia tri

# %%
#W4A2
n = int(input())
while n <= 0 :
    n = int(input())
if n > 0 and n % 1 == 0:
    if n > 1:
        la_so_nguyen_to = True 
        for i in range (2,n):
            if n % i == 0:
                la_so_nguyen_to = False
                break
        if la_so_nguyen_to:
            print(" la so nguyen to")
        else:
            print("khong la so nguyen to")
    else:
        print("khong la so nguyen to")
# Out:
#  la so nguyen to

# %%
#W4A3
n = int(input())
n_giai_thua = 1
for i in range(1,n+1):
    if n <= 99:
        n_giai_thua *= i
    else:
        n_giai_thua = "khong co gia tri"
print(n_giai_thua)
# Out:
# 185482642257398439114796845645546284380220968949399346684421580986889562184028199319100141244804501828416633516851200000000000000000000

# %%
#W4A4
n = abs(int(input()))
if n == 0:
    print("1")
else:
    dem = 0
    while n > 0:
        dem = dem + 1
        n = n // 10
print(dem)
# Out:
# 6

# %%
#W4A5
n = int(input())
so = list(map(int, input().split()))
if n >= 2 and len(so) == n:
    tim_thay = False
    for i in so :
        if i == 42 :
            tim_thay = True
            break
    if tim_thay:
        print("I've found the meaning of life!")
    else:
        print("It's a joke!")
# Out:
# I've found the meaning of life!

# %%
#W4A6
a , b = map(int, input().split()) 
if a > 0 and b > 0 and a <= b:  
        Tong = 0
        for i in range(a , b+1):
            if i > 1:
                la_snt = True
                for j in range(2,i):
                    if i % j == 0 :
                        la_snt = False
                        break
                if la_snt:
                    Tong = Tong + i
print(Tong)
# Out:
# 17

# %%
while True:
    a , b = map(int, input().split())
    if a > 0 and b > 0 and b >= a:
            break
Tong = 0
for i in range(a , b+1):
    if i > 1:
        la_snt = True
        for j in range(2,i):
            if i % j == 0 :
                la_snt = False
                break
        if la_snt:
            Tong = Tong + i
print(Tong)
# Out:
# 17

# %%
#W4A7
###đk so nguyen duong => TH1: n la so nguyen to -> Untln la chinh no =>TH2: n khong la so nt => chia cho cac so nto tu (2,n)
n = int(input())
if n >=2 :
    la_so_nguyen_to = True
    for i in range(2, n):
        if n % i == 0:
            la_so_nguyen_to = False
            break
    if la_so_nguyen_to:
        print(n)
    else:
        uoc_nguyen_to = []
        for j in range (2, n):
            la_so_nguyen_to_2 = True
            for k in range(2,j):
                if j % k == 0: 
                    la_so_nguyen_to_2 = False
                    break
            if la_so_nguyen_to_2:
                if n % j == 0:
                    uoc_nguyen_to.append(j)
    print(max(uoc_nguyen_to))
# Out:
# 3

# %%
#W4A8
###palindrome : vd 5665 viet nguoc lai van la 5665
n = input()
so_buoc = 0
while n != n[::-1]:
    reverse = n[::-1]
    n = str(int(n) + int(reverse))
    so_buoc = so_buoc + 1
print(so_buoc , n)
# Out:
# 1 55

# %%
#W4A9
n = int(input())
so_chinh_phuong = []
for i in range(1,n+1):
    if (int(i**(1/2)))**2 == i:
        so_chinh_phuong.append(i)
if len(so_chinh_phuong) > 0:
    print(so_chinh_phuong)
else:
    print("No Number")
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
#W4A10
n = int(input())
do_dai_day = []
for x in range(1, n + 1):
    if x % 2 == 0:
        x = x / 2
    else:
        x = 3*x + 1
# Out:
# []

# %%
#W4A10
#Cách tạo ra dãy CollatzBắt đầu với bất kỳ số nguyên dương $n$ nào, bạn thực hiện các bước sau liên tiếp
#neu la so chan thi chia so do cho 2(n/2)
#neu la so le thi nhan voi 3 roi cong 1 ( 3n + 1)
#thuc hien lien tuc cho den khi vong lap 4-2-1 
n = int(input())
L = 0
do_dai_day = []
while i < n:
    while i != 1:
        if i % 2 == 0 :
            i = i // 2
        else:
            i = 3*i + 1
        L = L + 1

        

print(x,L)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 10
#       8 do_dai_day = []
#       9 while i < n:
# ---> 10     while i != 1:
#      11         if i % 2 == 0 :
#      12             i = i // 2
#
# KeyboardInterrupt:

# %%
#W4A11
n = int(input())
so_luong_uoc_chan = []
for i in range(1, n + 1):
    if 0 < n < (10)**6 and n % i == 0 and i % 2 == 0:
        so_luong_uoc_chan.append(i)
print(len(so_luong_uoc_chan))
# Out:
# 6

# %%
#W4A12
x = float(input())
n = int(input())
tien_rut_duoc = x*((1 + (7/100))**(n))
print(int(tien_rut_duoc))
# Out:
# 278048341

# %%
#W4A12-C2
x = int(input())
n = int(input())
tong_tien_rut_duoc = x
so_thang = 1
while so_thang <= n :
    tong_tien_rut_duoc = tong_tien_rut_duoc*(1 + (7/100))
    so_thang = so_thang + 1
print(int(tong_tien_rut_duoc))
# Out:
# 305851

# %%
#W4A13
a , b = map(int, input().split())
uoc_cua_b = []
uoc_cua_a = []
tong_cac_uoc = 0
if a < b :
    for i in range(1,b):
        if b % i == 0:
            uoc_cua_b.append(i)
            tong_cac_uoc = tong_cac_uoc + i
    if tong_cac_uoc == a:
        print("true")
    else:
        print("false")
elif b < a:
    for i in range(1,a):
        if a % i == 0:
            uoc_cua_a.append(i)
            tong_cac_uoc = tong_cac_uoc + i
    if tong_cac_uoc == b:
        print("true")
    else:
        print("false")
else:
    print("false")
# Out:
# false

# %%
#W4A14
m , n = map(int, input().split())
uoc_chung_ln = []
if m == n:
    print(m)
elif m > n :
    for i in range(1,m):
        if m % i == 0 and n % i == 0:
            uoc_chung_ln.append(i)
    print(max(uoc_chung_ln))
else:
    for i in range(1,n):
        if m % i == 0 and n % i == 0:
            uoc_chung_ln.append(i)
    print(max(uoc_chung_ln))
# Out:
# 4

# %%
#W4A15
so_con = int(input())
so_chan = int(input())
so_ga = 0
so_cho = 0
for i in range(0,(so_chan)//2):
    for j in range((so_chan)//4):
        if i*2 + j*4 == so_chan and i + j == so_con :
            so_ga = so_ga + i
            so_cho = so_cho + j
if so_con == so_ga + so_cho and so_chan == so_ga*2 + so_cho*4:
    print(so_ga, so_cho)
else:
    print("Invalid")
# Out:
# 10 25

# %%
#W4A15 - y tuong
#dao nguoc cach tim - goi a la so ga , b la so cho, so chan bat ki
#-> 2*a + 4*b = so chan
#khoang gia tri cua a se thuoc [0;so chan/2], cua b se thuoc [0; so chan/4]
#quay lai bai toan : ta co san a va b , so chan bat ki, a + b = so con
#vd: 120 chan va 10 con ga 25 con cho -> thoa man 
#bieu thuc 1 : a + b = so con
#bieu thuc 2 : 2*a + 4*b = so chan

# %%
#W4A16
for i in range(0,100):
    if i % 3 == 0 and i % 2 == 0:
        print(i)
# Out:
# 0
# 6
# 12
# 18
# 24
# 30
# 36
# 42
# 48
# 54
# 60
# 66
# 72
# 78
# 84
# 90
# 96

# %%
#W4A17
a = int(input())
for i in range(1,a*10 + 1):
    if i % a == 0:
        print(i)
# Out:
# 12
# 24
# 36
# 48
# 60
# 72
# 84
# 96
# 108
# 120

# %%
#W4A18
a , b = map(int , input().split())
if a == b :
    for i in range(1,a + 1):
        if a % i == 0:
            print(i)
elif a > b :
    for i in range(1,a):
        if a % i == 0 and b % i == 0:
            print(i)
else:
    for i in range(1,b):
        if a % i == 0 and b % i == 0:
            print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 12

# %%
#W4A19
n = int(input())
for i in range(1,n):
    if n <= 1000 and i % 2 == 0 and i <= n:
        print(i)
    else:
        print("False")
# Out:
# 2
# 4
# 6
# 8

# %%
#W4A20
n = int(input())
co_dang_2muk = False
for k in range(1, n):
    if n**(1/k) == 2:
        co_dang_2muk = True
        break
if co_dang_2muk:
    print("True")
else:
    print("False")
# Out:
# True

# %%
#W4A21
n = int(input())
tong_cac_so = 0
while n > 0 :
    m = n % 10
    n = n // 10
    tong_cac_so = tong_cac_so + m
print(tong_cac_so)
# Out:
# 10

# %%
#W4A22
n = int(input())
dem_chan = 0
dem_le = 0
while n > 0:
    m = n % 10
    n = n // 10
    if m % 2 == 0:
        dem_chan = dem_chan + 1
    else:
        dem_le = dem_le + 1
print(dem_chan)
print(dem_le)
# Out:
# 5
# 1

# %%
#W4A23
n = int(input())
k = 1
while (k*(k + 1))//2 < n:
    k = k + 1
print(k-1)
# Out:
# 3

# %%
#W4A24
a = int(input())
tong = 0
n = 0
while tong <= a:
    n = n + 1
    tong = tong + 1/n
print(n)
# Out:
# 11

# %%
#W4A25
while True:
    list_nguyen = list(map(int, input().split()))
    if -1 in list_nguyen:
        break
    print(max(list_nguyen), min(list_nguyen))

# %%
#W4A26
n = int(input())
m1 = 1
m2 = 1
while m2 <= n:
    m3 = m2 + m1
    m1 = m2
    m2 = m3
print(m1)
# Out:
# 13

# %%
#W4A27
chuoi_ki_tu = input()
do_dai_chuoi = 0
for ky_tu in chuoi_ki_tu:
    do_dai_chuoi = do_dai_chuoi + 1
so_tu = 0
for i in range(do_dai_chuoi):
    if chuoi_ki_tu[i-1] == " " or i == 0:
        so_tu = so_tu + 1
print(so_tu)
# Out:
# 3

# %%
#W4A28
chuoi_ki_tu = input()
tu_dau_tien = " "
for i in range(len(chuoi_ki_tu)):
    if chuoi_ki_tu[i] == " ":
        break
    tu_dau_tien = tu_dau_tien + chuoi_ki_tu[i]
print(tu_dau_tien)
# Out:
#  ba

# %%
#W4A29
n = input()
x = ""
for i in n:
    if i.islower():
        x = x + i.upper()
    else:
        x = x + i.lower()
print(x)
# Out:
# ABCdef

# %%
#W4A30
chuoi = map(int, input().split(","))
tong = 0
for i in chuoi:
    tong = tong + i
print(tong)
# Out:
# 12

# %%
#W4A31
chuoi = input()
