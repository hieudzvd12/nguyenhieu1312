# %%
#W3A1
n = int(input())
print(str(n)[::-1])
# Out:
# 3435

# %%
#W3A2
a = int(input())
b = int(input())
a = a^b
b = a^b
a = a^b
print(a , b)
# Out:
# 5 5

# %%
#W3A3
n = int(input())
if n > 0 and (n & n-1) == 0:
    print("True")
else:
    print("False")
# Out:
# True

# %%
#W3A4
m , n = map(float , input().split())
if m % n == 0:
    print(m/n)
elif (m/n) > 0:
    print(int(m/n))
else:
    print(int(m/n)-1)
# Out:
# 51

# %%
#W3A5
m , n = map(float , input().split())
if m % n == 0:
    print(m/n)
elif (m/n) > 0:
    print(int(m/n) + 1)
else:
    print(int(m/n))
# Out:
# 10

# %%
#W3A6
x = int(input())
if x % 2 == 0 and x > 0:
    print("Even")
else:
    print("Odd")
# Out:
# Odd

# %%
#W3A7
a , b = map(int, input().split())
if a < 0 and b < 0 :
    print("Yes")
else:
    print("No")
# Out:
# No

# %%
#W3A8
a = input()
b = input()
if len(a) > len(b):
    print("True")
else:
    print("false")
# Out:
# True

# %%
#W3A9
a , b , c = map(float , input().split())
if a + b > c and a + c > b and b + c > a:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
#W3A10
a , b , c , d = map(int , input().split())
print(max(a , b , c , d))
# Out:
# 8

# %%
#W3A11
a , b , c = map(float , input().split())
if a + b > c and a + c > b and b + c > a:
    if a == b != c or a == c != b or b == c != a:
        print("day la tam giac can")
    elif a == b == c :
        print("day la tam giac deu")
    elif a**2 + b**2 == c**2 or a**2 + c**2 == b**2 or b**2 + c**2 == a**2:
        print("day la tam giac vuong")
    else :
        print("day la tam giac thuong")
else:
    print("khong la ba canh cua mot tam giac")
# Out:
# day la tam giac deu

# %%
#W3A12
n = int(input())
if n > 0 and (n % 4 == 0 and n % 100 != 0) or (n % 400 == 0):
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
#W3A13
kWh = float(input())
if 0 <= kWh <= 50 :
    print(kWh*1500)
elif 51 <= kWh <= 100:
    print(1500*50 + (kWh-50)*2000)
else:
    print(1500*50 + 2000*50 + 3000*(kWh-100))
# Out:
# 175000.0

# %%
#W3A14
a = float(input())
b = float(input())

if a != 0:
    x = -b / a
    print(f"Phương trình có nghiệm duy nhất x = {x}")
else:
    if b == 0:
        print("Phương trình có vô số nghiệm")
    else:
        print("Phương trình vô nghiệm")
# Out:
# pt co nghiem duy nhat : -1.12

# %%
#W3A15
diem_tb = float(input())
if 0 <= diem_tb < 5:
    print("Yeu")
elif 5 <= diem_tb < 6.5 :
    print("Trung Binh")
elif 6.5 <= diem_tb < 8:
    print("Kha")
else:
    print("Gioi")
# Out:
# Trung Binh

# %%
#W3A16
m = float(input())
if m - int(m) == 0:
    print(m) 
    print(m)
    print(m)
else:
    if m > 0:
        print(int(m)+1)
        print(int(m))
        if m - int(m) >= 0.5:
            print(int(m)+1)
        else:
            print(int(m))
    else:
        print(int(m))
        print(int(m)-1)
        if m - int(m) <= -0.5:
            print(int(m)-1)
        else:
            print(int(m))
# Out:
# 8
# 7
# 7

# %%
m = float(input())
if m - int(m) == 0:
    print(m) 
    print(m)
    print(m)
else:
    if m > 0:
        if m - int(m) >= 0.5:
             print(int(m)+1,int(m),int(m)+1)
        else:
            print(int(m)+1,int(m),int(m))
    else:
        if m - int(m) <= -0.5:
            print(int(m),int(m)-1,int(m)-1)
        else:
            print(int(m),int(m)-1,int(m)-1)
# Out:
# 8 7 7

# %%
#W3A17
a , b , c , d = map(float , input().split())
if b/a == c/b == d/c:
    print("Yes")
else:
    print("No")
# Out:
# No

# %%
#W3A1-1
so = int(input())
hangdv = (so // 1) % 10
hangnghin = (so // 1000) % 10
print(hangdv)
print(hangnghin)
# Out:
# 7
# 1

# %%
#W3A999-lam tron den chu so thu k (khong dung ham)
n = float(input())
k = int(input())
n = int(n*10**(k+1))
a = n % 10
if a >= k:
    n = n // 10 +1
else:
    n = n // 10
print(n / 10**(k))
# Out:
# 12.124
